# %%
import tensorflow as tf
from tensorflow import keras

print("TensorFlow version:", tf.__version__)
print("Keras version:", keras.__version__)
# Out:
# TensorFlow version: 2.16.2
# Keras version: 3.11.3

# %%
import pandas as pd
import numpy as np
from hyperopt import STATUS_OK,Trials,fmin,hp,tpe
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import mlflow
from mlflow.models import infer_signature

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
wine_quality = fetch_ucirepo(id=186) 
  
# data (as pandas dataframes) 
X = wine_quality.data.features 
y = wine_quality.data.targets 
  
# metadata 
print(wine_quality.metadata) 
  
# variable information 
print(wine_quality.variables)
# Out:
# {'uci_id': 186, 'name': 'Wine Quality', 'repository_url': 'https://archive.ics.uci.edu/dataset/186/wine+quality', 'data_url': 'https://archive.ics.uci.edu/static/public/186/data.csv', 'abstract': 'Two datasets are included, related to red and white vinho verde wine samples, from the north of Portugal. The goal is to model wine quality based on physicochemical tests (see [Cortez et al., 2009], http://www3.dsi.uminho.pt/pcortez/wine/).', 'area': 'Business', 'tasks': ['Classification', 'Regression'], 'characteristics': ['Multivariate'], 'num_instances': 4898, 'num_features': 11, 'feature_types': ['Real'], 'demographics': [], 'target_col': ['quality'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2009, 'last_updated': 'Wed Nov 15 2023', 'dataset_doi': '10.24432/C56S3T', 'creators': ['Paulo Cortez', 'A. Cerdeira', 'F. Almeida', 'T. Matos', 'J. Reis'], 'intro_paper': {'ID': 252, 'type': 'NATIVE', 'title': 'Modeling wine preferences by data mining from physicochemical properties', 'authors': 'P. Cortez, A. Cerdeira, Fernando Almeida, Telmo Matos, J. Reis', 'venue': 'Decision Support Systems', 'year': 2009, 'journal': None, 'DOI': None, 'URL': 'https://www.semanticscholar.org/paper/Modeling-wine-preferences-by-data-mining-from-Cortez-Cerdeira/bf15a0ccc14ac1deb5cea570c870389c16be019c', 'sha': None, 'corpus': None, 'arxiv': None, 'mag': None, 'acl': None, 'pmid': None, 'pmcid': None}, 'additional_info': {'summary': 'The two datasets are related to red and white variants of the Portuguese "Vinho Verde" wine. For more details, consult: http://www.vinhoverde.pt/en/ or the reference [Cortez et al., 2009].  Due to privacy and logistic issues, only physicochemical (inputs) and sensory (the output) variables are available (e.g. there is no data about grape types, wine brand, wine selling price, etc.).\n\nThese datasets can be viewed as classification or regression tasks.  The classes are ordered and not balanced (e.g. there are many more normal wines than excellent or poor ones). Outlier detection algorithms could be used to detect the few excellent or poor wines. Also, we are not sure if all input variables are relevant. So it could be interesting to test feature selection methods.\n', 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': 'For more information, read [Cortez et al., 2009].\r\nInput variables (based on physicochemical tests):\r\n   1 - fixed acidity\r\n   2 - volatile acidity\r\n   3 - citric acid\r\n   4 - residual sugar\r\n   5 - chlorides\r\n   6 - free sulfur dioxide\r\n   7 - total sulfur dioxide\r\n   8 - density\r\n   9 - pH\r\n   10 - sulphates\r\n   11 - alcohol\r\nOutput variable (based on sensory data): \r\n   12 - quality (score between 0 and 10)', 'citation': None}}
#                     name     role         type demographic  \
# 0          fixed_acidity  Feature   Continuous        None
# 1       volatile_acidity  Feature   Continuous        None
# 2            citric_acid  Feature   Continuous        None
# 3         residual_sugar  Feature   Continuous        None
# 4              chlorides  Feature   Continuous        None
# 5    free_sulfur_dioxide  Feature   Continuous        None
# 6   total_sulfur_dioxide  Feature   Continuous        None
# 7                density  Feature   Continuous        None
# 8                     pH  Feature   Continuous        None
# 9              sulphates  Feature   Continuous        None
# 10               alcohol  Feature   Continuous        None
# 11               quality   Target      Integer        None
# 12                 color    Other  Categorical        None
#
#                description units missing_values
# 0                     None  None             no
# 1                     None  None             no
# 2                     None  None             no
# 3                     None  None             no
# 4                     None  None             no
# 5                     None  None             no
# 6                     None  None             no
# 7                     None  None             no
# 8                     None  None             no
# 9                     None  None             no
# 10                    None  None             no
# 11  score between 0 and 10  None             no
# 12            red or white  None             no

# %%
ind_df=pd.DataFrame(X)
target_df=pd.DataFrame(y)

data=ind_df
data['quality']=target_df

# %%
data
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 6492     11.2        6
# 6493      9.6        5
# 6494      9.4        6
# 6495     12.8        7
# 6496     11.8        6
#
# [6497 rows x 12 columns]

# %%
##Loading and splitting data
ind_df = pd.DataFrame(X)
target_df = pd.DataFrame(y)

data = ind_df.copy()  # ✅ make an independent copy
data['quality'] = target_df

# Split into features and target
ind_data = data.drop(columns=['quality'])
dep_data = data['quality']

# Train/test split (with reproducibility)
X_train, X_test, y_train, y_test = train_test_split(ind_data, dep_data, test_size=0.20, random_state=42)

# Validation split (also reproducible)
train_x, valid_x, train_y, valid_y = train_test_split(X_train, y_train, test_size=0.20, random_state=42)

# %%
def train_model(params,epochs,train_x,train_y,valid_x,valid_y,test_x,test_y):
    ##model arch
    mean_s=np.mean(train_x,axis=0)
    var=np.var(train_x,axis=0)
    model=keras.Sequential(
        [keras.Input([train_x.shape[1]]),
        keras.layers.Normalization(mean=mean_s,variance=var),
        keras.layers.Dense(64,activation='relu'),
        keras.layers.Dense(1)])
    ##Compile. the model
    model.compile(optimizer=keras.optimizers.SGD(learning_rate=params['lr'],momentum=params['momentum']),
    loss='mean_squared_error',
    metrics=[keras.metrics.RootMeanSquaredError()])
    
    ##Train the model
    with mlflow.start_run(nested=True):
        model.fit(train_x,train_y, validation_data=(valid_x, valid_y),epochs=epochs,batch_size=64)
        ##Evaluate the model
        eval_result=model.evaluate(valid_x,valid_y,batch_size=64)
        eval_rmse=eval_result[1]
        ##signature
        train_x_np = np.array(train_x, dtype=np.float32)
        preds=model.predict(train_x_np)
        signature=infer_signature(train_x_np,preds)

        ##log the params and result
        mlflow.log_params(params)
        mlflow.log_metric('eval_rmse',eval_rmse)

        ##Log the model
        mlflow.tensorflow.log_model(model,'model',signature=signature)
    return {
        'loss': eval_rmse,
        'status': STATUS_OK,
        'model': model
    }

# %%
##Objective function
def objective(params):
    result = train_model(
        params,
        epochs=3,
        train_x=train_x,
        train_y=train_y,
        valid_x=valid_x,
        valid_y=valid_y,
        test_x=X_test,
        test_y=y_test
    )
    return result

# %%
space = {
    "lr": hp.loguniform('lr', np.log(1e-5), np.log(1e-1)),   # learning rate between 1e-5 and 1e-1
    "momentum": hp.uniform('momentum', 0.1, 0.9)             # momentum between 0.1 and 0.9
}

# %%
##before running this make sure to be in you dev env and running mlflow ui suing terminal
mlflow.set_experiment("/wine-quality")
with mlflow.start_run():
    trials=Trials()
    best=fmin(
        fn=objective,
        space=space,
        algo=tpe.suggest,
        max_evals=4,
        trials=trials
    )
    best_run=sorted(trials.results,key=lambda x: x['loss'])[0]
    mlflow.log_params(best)
    mlflow.log_metric('eval_rmse',best_run['loss'])

    ##Log the model
    best_model = best_run["model"]
    import numpy as np
    from mlflow.models.signature import infer_signature
    train_x_np = np.array(train_x, dtype=np.float32)
    preds = best_model.predict(train_x_np)
    correct_signature = infer_signature(train_x_np, preds)
    mlflow.tensorflow.log_model(best_run["model"],'model',signature=correct_signature)
    print(f'Best parameters :{best}')
    print(f"Best eval rmse :{best_run['loss']}")
# Out:
# Epoch 1/3
#
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 1:02 979ms/step - loss: 34.7373 - root_mean_squared_error: 5.8938
#  3/65 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 34.1690 - root_mean_squared_error: 5.8453
#  5/65 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 34.1857 - root_mean_squared_error: 5.8468
#  6/65 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 34.1750 - root_mean_squared_error: 5.8459
#  7/65 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 34.1281 - root_mean_squared_error: 5.8419
#  8/65 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 34.1155 - root_mean_squared_error: 5.8408
# 10/65 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 34.1533 - root_mean_squared_error: 5.8440
# 12/65 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 34.1735 - root_mean_squared_error: 5.8458
# 14/65 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 34.2088 - root_mean_squared_error: 5.8488
# 16/65 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 34.2179 - root_mean_squared_error: 5.8496
# 20/65 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 34.1655 - root_mean_squared_error: 5.8451
# 24/65 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 34.1020 - root_mean_squared_error: 5.8397
# 25/65 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 34.0844 - root_mean_squared_error: 5.8381
# 26/65 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 34.0665 - root_mean_squared_error: 5.8366
# 28/65 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 34.0382 - root_mean_squared_error: 5.8342
# 30/65 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 34.0081 - root_mean_squared_error: 5.8316
# 31/65 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 33.9923 - root_mean_squared_error: 5.8302
# 32/65 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 33.9776 - root_mean_squared_error: 5.8290
# 34/65 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 33.9496 - root_mean_squared_error: 5.8266
# 36/65 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 33.9148 - root_mean_squared_error: 5.8236
# 38/65 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 33.8784 - root_mean_squared_error: 5.8204
# 40/65 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 33.8453 - root_mean_squared_error: 5.8176
# 43/65 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 33.7946 - root_mean_squared_error: 5.8132
# 46/65 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 33.7412 - root_mean_squared_error: 5.8086
# 49/65 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 33.6838 - root_mean_squared_error: 5.8036
# 51/65 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 33.6437 - root_mean_squared_error: 5.8001
# 53/65 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 33.6018 - root_mean_squared_error: 5.7965
# 55/65 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 33.5608 - root_mean_squared_error: 5.7929
# 57/65 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 33.5195 - root_mean_squared_error: 5.7894
# 60/65 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 33.4593 - root_mean_squared_error: 5.7841
# 63/65 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 33.3997 - root_mean_squared_error: 5.7789
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 33.3599 - root_mean_squared_error: 5.7755
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 32.0820 - root_mean_squared_error: 5.6641 - val_loss: 29.7825 - val_root_mean_squared_error: 5.4573
#
# Epoch 2/3
#
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 32.6527 - root_mean_squared_error: 5.7143
#  4/65 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 31.3802 - root_mean_squared_error: 5.6012
#  7/65 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 30.7671 - root_mean_squared_error: 5.5461
#  8/65 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 30.6393 - root_mean_squared_error: 5.5346
# 10/65 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 30.4401 - root_mean_squared_error: 5.5166
# 11/65 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 30.3641 - root_mean_squared_error: 5.5097
# 13/65 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 30.2629 - root_mean_squared_error: 5.5006
# 15/65 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 30.1649 - root_mean_squared_error: 5.4917
# 17/65 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 30.0815 - root_mean_squared_error: 5.4841
# 19/65 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 29.9954 - root_mean_squared_error: 5.4763
# 21/65 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 29.9125 - root_mean_squared_error: 5.4687
# 23/65 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 29.8422 - root_mean_squared_error: 5.4623
# 25/65 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 29.7710 - root_mean_squared_error: 5.4557
# 28/65 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 29.6640 - root_mean_squared_error: 5.4459
# 31/65 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 29.5665 - root_mean_squared_error: 5.4369
# 34/65 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 29.4742 - root_mean_squared_error: 5.4284
# 37/65 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 29.3811 - root_mean_squared_error: 5.4198
# 40/65 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 29.2922 - root_mean_squared_error: 5.4116
# 43/65 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 29.2016 - root_mean_squared_error: 5.4032
# 47/65 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 29.0807 - root_mean_squared_error: 5.3919
# 51/65 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 28.9662 - root_mean_squared_error: 5.3812
# 54/65 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 28.8872 - root_mean_squared_error: 5.3738
# 57/65 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 28.8107 - root_mean_squared_error: 5.3666
# 59/65 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 28.7616 - root_mean_squared_error: 5.3620
# 61/65 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 28.7134 - root_mean_squared_error: 5.3575
# 63/65 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 28.6659 - root_mean_squared_error: 5.3531
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 28.6196 - root_mean_squared_error: 5.3487
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 27.1392 - root_mean_squared_error: 5.2095 - val_loss: 25.1347 - val_root_mean_squared_error: 5.0135
#
# Epoch 3/3
#
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 22.4847 - root_mean_squared_error: 4.7418
#  4/65 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 23.8543 - root_mean_squared_error: 4.8834
#  7/65 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 24.1305 - root_mean_squared_error: 4.9118
# 10/65 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 24.2499 - root_mean_squared_error: 4.9240
# 12/65 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 24.2812 - root_mean_squared_error: 4.9273
# 15/65 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 24.3239 - root_mean_squared_error: 4.9317
# 18/65 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 24.3074 - root_mean_squared_error: 4.9300
# 21/65 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 24.2906 - root_mean_squared_error: 4.9284
# 24/65 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 24.2550 - root_mean_squared_error: 4.9248
# 26/65 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 24.2333 - root_mean_squared_error: 4.9226
# 29/65 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 24.2037 - root_mean_squared_error: 4.9196
# 32/65 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 24.1647 - root_mean_squared_error: 4.9156
# 34/65 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 24.1385 - root_mean_squared_error: 4.9129
# 37/65 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 24.0985 - root_mean_squared_error: 4.9088
# 40/65 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 24.0581 - root_mean_squared_error: 4.9047
# 43/65 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 24.0194 - root_mean_squared_error: 4.9008
# 45/65 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 23.9911 - root_mean_squared_error: 4.8979
# 48/65 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 23.9527 - root_mean_squared_error: 4.8939
# 51/65 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 23.9150 - root_mean_squared_error: 4.8901
# 54/65 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 23.8759 - root_mean_squared_error: 4.8861
# 57/65 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 23.8358 - root_mean_squared_error: 4.8819
# 60/65 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 23.7947 - root_mean_squared_error: 4.8777
# 63/65 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 23.7512 - root_mean_squared_error: 4.8732
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 22.7624 - root_mean_squared_error: 4.7710 - val_loss: 20.9498 - val_root_mean_squared_error: 4.5771
#
#  1/17 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 19.9967 - root_mean_squared_error: 4.4718
#  5/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 20.8226 - root_mean_squared_error: 4.5628
#  9/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 21.0938 - root_mean_squared_error: 4.5925
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 21.1173 - root_mean_squared_error: 4.5951
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 21.0938 - root_mean_squared_error: 4.5926
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 20.9498 - root_mean_squared_error: 4.5771
#
#   1/130 ━━━━━━━━━━━━━━━━━━━━ 12s 99ms/step
#  11/130 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#  20/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  29/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  40/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  52/130 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#  63/130 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#  66/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  74/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  83/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  91/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 102/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 112/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 121/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 128/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
#
#   0%|          | 0/4 [00:09<?, ?trial/s, best loss=?]
# 2025/10/16 17:03:12 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
#
# 2025/10/16 17:03:23 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /var/folders/f0/294p97s93kb2393j1clk22w00000gn/T/tmp5b_fuo01/model, flavor: tensorflow). Fall back to return ['tensorflow==2.16.2', 'cloudpickle==3.1.1']. Set logging level to DEBUG to see the full traceback.
# Epoch 1/3
#
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 53s 841ms/step - loss: 33.5983 - root_mean_squared_error: 5.7964
#  3/65 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 33.3436 - root_mean_squared_error: 5.7738
#  5/65 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 31.3541 - root_mean_squared_error: 5.5943
#  7/65 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 29.0621 - root_mean_squared_error: 5.3755
#  9/65 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 26.7703 - root_mean_squared_error: 5.1428
# 12/65 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 23.8595 - root_mean_squared_error: 4.8291
# 15/65 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 21.7279 - root_mean_squared_error: 4.5899
# 18/65 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 20.0272 - root_mean_squared_error: 4.3906
# 21/65 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 18.6170 - root_mean_squared_error: 4.2186
# 24/65 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 17.4520 - root_mean_squared_error: 4.0723
# 27/65 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 16.4502 - root_mean_squared_error: 3.9426
# 30/65 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 15.5729 - root_mean_squared_error: 3.8253
# 33/65 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 14.8017 - root_mean_squared_error: 3.7196
# 35/65 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 14.3359 - root_mean_squared_error: 3.6544
# 37/65 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 13.9029 - root_mean_squared_error: 3.5928
# 40/65 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 13.3082 - root_mean_squared_error: 3.5067
# 42/65 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 12.9441 - root_mean_squared_error: 3.4530
# 45/65 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 12.4403 - root_mean_squared_error: 3.3775
# 48/65 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 11.9805 - root_mean_squared_error: 3.3074
# 50/65 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 11.6955 - root_mean_squared_error: 3.2632
# 54/65 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 11.1709 - root_mean_squared_error: 3.1806
# 56/65 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 10.9288 - root_mean_squared_error: 3.1418
# 59/65 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 10.5882 - root_mean_squared_error: 3.0867
# 61/65 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 10.3750 - root_mean_squared_error: 3.0517
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 10.0737 - root_mean_squared_error: 3.0018
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 9.9779 - root_mean_squared_error: 2.9858
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 3.8466 - root_mean_squared_error: 1.9613 - val_loss: 0.5920 - val_root_mean_squared_error: 0.7694
#
# Epoch 2/3
#
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.3887 - root_mean_squared_error: 0.6235
#  4/65 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.4747 - root_mean_squared_error: 0.6876
#  7/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5203 - root_mean_squared_error: 0.7196
# 10/65 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5427 - root_mean_squared_error: 0.7351
# 13/65 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5514 - root_mean_squared_error: 0.7413
# 16/65 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5555 - root_mean_squared_error: 0.7443
# 19/65 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5578 - root_mean_squared_error: 0.7459
# 22/65 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5601 - root_mean_squared_error: 0.7476
# 25/65 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5626 - root_mean_squared_error: 0.7494
# 28/65 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5650 - root_mean_squared_error: 0.7510
# 31/65 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5669 - root_mean_squared_error: 0.7523
# 34/65 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5677 - root_mean_squared_error: 0.7529
# 37/65 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5685 - root_mean_squared_error: 0.7535
# 40/65 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5691 - root_mean_squared_error: 0.7539
# 43/65 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5699 - root_mean_squared_error: 0.7545
# 46/65 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5707 - root_mean_squared_error: 0.7550
# 50/65 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5715 - root_mean_squared_error: 0.7556
# 54/65 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5719 - root_mean_squared_error: 0.7559
# 55/65 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5719 - root_mean_squared_error: 0.7559
# 59/65 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5720 - root_mean_squared_error: 0.7560
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5726 - root_mean_squared_error: 0.7564
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5808 - root_mean_squared_error: 0.7621 - val_loss: 0.6031 - val_root_mean_squared_error: 0.7766
#
# Epoch 3/3
#
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.3266 - root_mean_squared_error: 0.5715
#  5/65 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4881 - root_mean_squared_error: 0.6956
#  8/65 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5061 - root_mean_squared_error: 0.7093
# 11/65 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5146 - root_mean_squared_error: 0.7157
# 14/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5175 - root_mean_squared_error: 0.7181
# 17/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5195 - root_mean_squared_error: 0.7197
# 21/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5205 - root_mean_squared_error: 0.7206
# 25/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5228 - root_mean_squared_error: 0.7223
# 29/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5254 - root_mean_squared_error: 0.7242
# 33/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5268 - root_mean_squared_error: 0.7253
# 37/65 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5292 - root_mean_squared_error: 0.7270
# 41/65 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5320 - root_mean_squared_error: 0.7289
# 46/65 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5354 - root_mean_squared_error: 0.7312
# 51/65 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5388 - root_mean_squared_error: 0.7336
# 58/65 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5435 - root_mean_squared_error: 0.7368
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5471 - root_mean_squared_error: 0.7392
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5822 - root_mean_squared_error: 0.7630 - val_loss: 0.6208 - val_root_mean_squared_error: 0.7879
#
#  1/17 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.4472 - root_mean_squared_error: 0.6687
#  6/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5468 - root_mean_squared_error: 0.7373
# 10/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5868 - root_mean_squared_error: 0.7641
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6045 - root_mean_squared_error: 0.7758
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.6078 - root_mean_squared_error: 0.7783
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6208 - root_mean_squared_error: 0.7879
#
#   1/130 ━━━━━━━━━━━━━━━━━━━━ 10s 82ms/step
#  10/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  19/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  29/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  37/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  48/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  57/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  65/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  74/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  83/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  92/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 103/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 111/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 118/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 126/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
#
#  25%|██▌       | 1/4 [00:27<01:00, 20.06s/trial, best loss: 4.577098846435547]
# 2025/10/16 17:03:30 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
#
# 2025/10/16 17:03:39 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /var/folders/f0/294p97s93kb2393j1clk22w00000gn/T/tmph4zruuxt/model, flavor: tensorflow). Fall back to return ['tensorflow==2.16.2', 'cloudpickle==3.1.1']. Set logging level to DEBUG to see the full traceback.
# Epoch 1/3
#
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 41s 654ms/step - loss: 35.3935 - root_mean_squared_error: 5.9492
#  5/65 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 34.6592 - root_mean_squared_error: 5.8871
#  9/65 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 34.6288 - root_mean_squared_error: 5.8846
# 15/65 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 34.5514 - root_mean_squared_error: 5.8780
# 20/65 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 34.4895 - root_mean_squared_error: 5.8727
# 24/65 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 34.4761 - root_mean_squared_error: 5.8716
# 28/65 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 34.4710 - root_mean_squared_error: 5.8712
# 32/65 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 34.4581 - root_mean_squared_error: 5.8701
# 35/65 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 34.4511 - root_mean_squared_error: 5.8695
# 38/65 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 34.4457 - root_mean_squared_error: 5.8690
# 42/65 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 34.4374 - root_mean_squared_error: 5.8683
# 47/65 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 34.4258 - root_mean_squared_error: 5.8673
# 50/65 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 34.4172 - root_mean_squared_error: 5.8666
# 53/65 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 34.4092 - root_mean_squared_error: 5.8659
# 57/65 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 34.4033 - root_mean_squared_error: 5.8654
# 61/65 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 34.3996 - root_mean_squared_error: 5.8651
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 34.3978 - root_mean_squared_error: 5.8649
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 34.3968 - root_mean_squared_error: 5.8649
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 34.3298 - root_mean_squared_error: 5.8592 - val_loss: 34.4744 - val_root_mean_squared_error: 5.8715
#
# Epoch 2/3
#
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 36.1487 - root_mean_squared_error: 6.0124
#  3/65 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 35.9752 - root_mean_squared_error: 5.9979
#  4/65 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 35.7541 - root_mean_squared_error: 5.9794
#  5/65 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 35.5358 - root_mean_squared_error: 5.9610
#  7/65 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 35.2366 - root_mean_squared_error: 5.9358
#  9/65 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 35.0731 - root_mean_squared_error: 5.9220
# 12/65 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 34.8921 - root_mean_squared_error: 5.9067
# 15/65 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 34.7552 - root_mean_squared_error: 5.8951
# 18/65 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 34.6234 - root_mean_squared_error: 5.8839
# 21/65 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 34.5219 - root_mean_squared_error: 5.8753
# 24/65 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 34.4526 - root_mean_squared_error: 5.8694
# 27/65 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 34.4011 - root_mean_squared_error: 5.8650
# 30/65 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 34.3467 - root_mean_squared_error: 5.8604
# 33/65 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 34.2986 - root_mean_squared_error: 5.8563
# 36/65 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 34.2585 - root_mean_squared_error: 5.8529
# 39/65 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 34.2219 - root_mean_squared_error: 5.8497
# 42/65 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 34.1879 - root_mean_squared_error: 5.8468
# 46/65 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 34.1473 - root_mean_squared_error: 5.8434
# 49/65 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 34.1151 - root_mean_squared_error: 5.8406
# 52/65 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 34.0850 - root_mean_squared_error: 5.8380
# 55/65 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 34.0552 - root_mean_squared_error: 5.8355
# 58/65 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 34.0275 - root_mean_squared_error: 5.8331
# 61/65 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 34.0005 - root_mean_squared_error: 5.8308
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33.9737 - root_mean_squared_error: 5.8285
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 33.4585 - root_mean_squared_error: 5.7843 - val_loss: 33.5966 - val_root_mean_squared_error: 5.7963
#
# Epoch 3/3
#
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 33.6375 - root_mean_squared_error: 5.7998
#  4/65 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 33.4161 - root_mean_squared_error: 5.7807
#  7/65 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 33.3652 - root_mean_squared_error: 5.7762
# 10/65 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 33.2397 - root_mean_squared_error: 5.7653
# 13/65 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 33.1424 - root_mean_squared_error: 5.7569
# 16/65 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 33.1012 - root_mean_squared_error: 5.7533
# 19/65 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 33.0670 - root_mean_squared_error: 5.7503
# 22/65 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 33.0392 - root_mean_squared_error: 5.7479
# 26/65 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 32.9969 - root_mean_squared_error: 5.7442
# 30/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 32.9566 - root_mean_squared_error: 5.7407
# 33/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 32.9412 - root_mean_squared_error: 5.7394
# 36/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 32.9271 - root_mean_squared_error: 5.7382
# 39/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 32.9147 - root_mean_squared_error: 5.7371
# 43/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 32.9058 - root_mean_squared_error: 5.7363
# 46/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 32.8952 - root_mean_squared_error: 5.7354
# 49/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 32.8822 - root_mean_squared_error: 5.7343
# 53/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 32.8673 - root_mean_squared_error: 5.7330
# 56/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 32.8546 - root_mean_squared_error: 5.7319
# 60/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 32.8380 - root_mean_squared_error: 5.7304
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 32.8232 - root_mean_squared_error: 5.7291
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 32.6104 - root_mean_squared_error: 5.7106 - val_loss: 32.7429 - val_root_mean_squared_error: 5.7221
#
#  1/17 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 33.4623 - root_mean_squared_error: 5.7847
#  6/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 32.7687 - root_mean_squared_error: 5.7242
# 11/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 32.9194 - root_mean_squared_error: 5.7374
# 15/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 32.8688 - root_mean_squared_error: 5.7331
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 32.7429 - root_mean_squared_error: 5.7221
#
#   1/130 ━━━━━━━━━━━━━━━━━━━━ 12s 95ms/step
#   9/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  20/130 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#  28/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  39/130 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#  48/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  57/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  66/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  73/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  80/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  88/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  93/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  98/130 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 106/130 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 111/130 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 116/130 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 122/130 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 124/130 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 129/130 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
#
#  50%|█████     | 2/4 [00:43<00:35, 17.79s/trial, best loss: 0.7879378795623779]
# 2025/10/16 17:03:46 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
#
# 2025/10/16 17:03:55 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /var/folders/f0/294p97s93kb2393j1clk22w00000gn/T/tmpi4kd59m6/model, flavor: tensorflow). Fall back to return ['tensorflow==2.16.2', 'cloudpickle==3.1.1']. Set logging level to DEBUG to see the full traceback.
# Epoch 1/3
#
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 53s 829ms/step - loss: 36.8073 - root_mean_squared_error: 6.0669
#  4/65 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 35.2597 - root_mean_squared_error: 5.9375
#  7/65 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 34.4442 - root_mean_squared_error: 5.8680
# 11/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 33.4436 - root_mean_squared_error: 5.7812
# 16/65 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 32.1179 - root_mean_squared_error: 5.6631
# 20/65 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 31.0414 - root_mean_squared_error: 5.5646
# 23/65 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 30.2411 - root_mean_squared_error: 5.4897
# 26/65 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 29.4605 - root_mean_squared_error: 5.4153
# 28/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 28.9491 - root_mean_squared_error: 5.3658
# 32/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 27.9519 - root_mean_squared_error: 5.2675
# 35/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 27.2338 - root_mean_squared_error: 5.1952
# 38/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 26.5410 - root_mean_squared_error: 5.1242
# 43/65 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 25.4470 - root_mean_squared_error: 5.0096
# 46/65 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 24.8253 - root_mean_squared_error: 4.9431
# 49/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 24.2284 - root_mean_squared_error: 4.8781
# 52/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 23.6549 - root_mean_squared_error: 4.8148
# 56/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 22.9264 - root_mean_squared_error: 4.7329
# 59/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 22.4069 - root_mean_squared_error: 4.6735
# 63/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 21.7485 - root_mean_squared_error: 4.5970
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 21.4336 - root_mean_squared_error: 4.5600
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.4353 - root_mean_squared_error: 3.3816 - val_loss: 0.8427 - val_root_mean_squared_error: 0.9180
#
# Epoch 2/3
#
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.7806 - root_mean_squared_error: 0.8835
#  4/65 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6714 - root_mean_squared_error: 0.8183
#  7/65 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6590 - root_mean_squared_error: 0.8111
# 11/65 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6550 - root_mean_squared_error: 0.8089
# 15/65 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6558 - root_mean_squared_error: 0.8095
# 18/65 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6511 - root_mean_squared_error: 0.8066
# 21/65 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6464 - root_mean_squared_error: 0.8037
# 24/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6439 - root_mean_squared_error: 0.8022
# 27/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6419 - root_mean_squared_error: 0.8010
# 30/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6397 - root_mean_squared_error: 0.7996
# 34/65 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6360 - root_mean_squared_error: 0.7973
# 38/65 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6324 - root_mean_squared_error: 0.7950
# 41/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6303 - root_mean_squared_error: 0.7937
# 44/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6278 - root_mean_squared_error: 0.7921
# 47/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6252 - root_mean_squared_error: 0.7904
# 50/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6225 - root_mean_squared_error: 0.7887
# 54/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6194 - root_mean_squared_error: 0.7867
# 57/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6174 - root_mean_squared_error: 0.7855
# 60/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6155 - root_mean_squared_error: 0.7843
# 63/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6138 - root_mean_squared_error: 0.7832
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5780 - root_mean_squared_error: 0.7603 - val_loss: 0.5969 - val_root_mean_squared_error: 0.7726
#
# Epoch 3/3
#
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.5614 - root_mean_squared_error: 0.7493
#  4/65 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5684 - root_mean_squared_error: 0.7538
#  7/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5752 - root_mean_squared_error: 0.7583
# 10/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5693 - root_mean_squared_error: 0.7545
# 13/65 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5655 - root_mean_squared_error: 0.7520
# 16/65 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5601 - root_mean_squared_error: 0.7483
# 20/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5546 - root_mean_squared_error: 0.7446
# 23/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5500 - root_mean_squared_error: 0.7415
# 27/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5443 - root_mean_squared_error: 0.7376
# 31/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5400 - root_mean_squared_error: 0.7346
# 35/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5385 - root_mean_squared_error: 0.7336
# 38/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5376 - root_mean_squared_error: 0.7330
# 40/65 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5370 - root_mean_squared_error: 0.7326
# 41/65 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5368 - root_mean_squared_error: 0.7325
# 44/65 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5360 - root_mean_squared_error: 0.7320
# 47/65 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5352 - root_mean_squared_error: 0.7314
# 50/65 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5344 - root_mean_squared_error: 0.7309
# 52/65 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5340 - root_mean_squared_error: 0.7306
# 55/65 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5336 - root_mean_squared_error: 0.7303
# 58/65 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5334 - root_mean_squared_error: 0.7302
# 61/65 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5334 - root_mean_squared_error: 0.7302
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5334 - root_mean_squared_error: 0.7302
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.5352 - root_mean_squared_error: 0.7316 - val_loss: 0.5862 - val_root_mean_squared_error: 0.7657
#
#  1/17 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.4456 - root_mean_squared_error: 0.6676
#  5/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5125 - root_mean_squared_error: 0.7143
#  9/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5565 - root_mean_squared_error: 0.7444
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5723 - root_mean_squared_error: 0.7551
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5778 - root_mean_squared_error: 0.7590
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5862 - root_mean_squared_error: 0.7657
#
#   1/130 ━━━━━━━━━━━━━━━━━━━━ 11s 93ms/step
#   8/130 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#  16/130 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#  24/130 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#  33/130 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#  41/130 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#  48/130 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#  57/130 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#  66/130 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#  74/130 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#  84/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  91/130 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  96/130 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 100/130 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 102/130 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 104/130 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 111/130 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 116/130 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 122/130 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 128/130 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
#
#  75%|███████▌  | 3/4 [00:59<00:17, 17.04s/trial, best loss: 0.7879378795623779]
# 2025/10/16 17:04:03 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
#
# 2025/10/16 17:04:11 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /var/folders/f0/294p97s93kb2393j1clk22w00000gn/T/tmp32eex6no/model, flavor: tensorflow). Fall back to return ['tensorflow==2.16.2', 'cloudpickle==3.1.1']. Set logging level to DEBUG to see the full traceback.
# 100%|██████████| 4/4 [01:08<00:00, 17.17s/trial, best loss: 0.765654981136322]
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2025/10/16 17:04:12 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/10/16 17:04:21 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /var/folders/f0/294p97s93kb2393j1clk22w00000gn/T/tmph5ga3jfk/model, flavor: tensorflow). Fall back to return ['tensorflow==2.16.2', 'cloudpickle==3.1.1']. Set logging level to DEBUG to see the full traceback.
# Best parameters :{'lr': 0.0013731016466518, 'momentum': 0.7352551333441845}
# Best eval rmse :0.765654981136322

# %%
##Inferencing : we can load the best model form model flow ui
from mlflow.models import validate_serving_input
model_uri='models:/m-b34793258c1340b5a27cbb9073a72b11' ##model uri  with lowest rmse of .76 
from mlflow.models import convert_input_example_to_serving_input
serving_payload=convert_input_example_to_serving_input(X_test)
validate_serving_input(model_uri,serving_payload)
# Out:
# Downloading artifacts: 100%|██████████| 7/7 [00:00<00:00, 2551.06it/s]
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# array([[6.513489 ],
#        [5.0877047],
#        [6.256715 ],
#        ...,
#        [6.7648506],
#        [5.3786   ],
#        [5.5734005]], dtype=float32)

# %%
###Inferencing using pyfuncModel
model_uri='models:/m-b34793258c1340b5a27cbb9073a72b11'
loaded_model=mlflow.pyfunc.load_model(model_uri)

##Predicting 
X_test_np = X_test.astype(np.float32) 
loaded_model.predict(X_test_np)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step
# array([[6.513489 ],
#        [5.0877047],
#        [6.256715 ],
#        ...,
#        [6.7648506],
#        [5.3786   ],
#        [5.5734005]], dtype=float32)
